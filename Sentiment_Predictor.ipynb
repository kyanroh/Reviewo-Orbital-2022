# %% [markdown]
# ###Importing libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ###Importing dataset (from google drive)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dataset = pd.read_csv('./drive/MyDrive/Orbital Python files/a2_RestaurantReviews_FreshDump.tsv', delimiter = '\t', quoting = 3)
dataset.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-080c5ca0bc13> in <module>()
# ----> 1 dataset = pd.read_csv('./drive/MyDrive/Orbital Python files/a2_RestaurantReviews_FreshDump.tsv', delimiter = '\t', quoting = 3)
#       2 dataset.head()
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %% [markdown]
# ###Data cleaning

# %%
import re
import nltk

nltk.download('stopwords')

from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

all_stopwords = stopwords.words('english')
all_stopwords.remove('not')

# %%
corpus=[]

for i in range(0, 100):
  review = re.sub('[^a-zA-Z]', ' ', dataset['Review'][i])
  review = review.lower()
  review = review.split()
  review = [ps.stem(word) for word in review if not word in set(all_stopwords)]
  review = ' '.join(review)
  corpus.append(review)

# %% [markdown]
# ###Data transformation

# %%
# Loading BoW dictionary
from sklearn.feature_extraction.text import CountVectorizer
import pickle
cvFile='./drive/MyDrive/Orbital Python files/c1_BoW_Sentiment_Model.pkl'
# cv = CountVectorizer(decode_error="replace", vocabulary=pickle.load(open('./drive/MyDrive/Colab Notebooks/2 Sentiment Analysis (Basic)/3.1 BoW_Sentiment Model.pkl', "rb")))
cv = pickle.load(open(cvFile, "rb"))

# %%
X_fresh = cv.transform(corpus).toarray()
X_fresh.shape

# %% [markdown]
# ###Predictions (via sentiment classifier)

# %%
import joblib
classifier = joblib.load('./drive/MyDrive/Orbital Python files/c2_Classifier_Sentiment_Model')

# %%
y_pred = classifier.predict(X_fresh)
print(y_pred)

# %%
dataset['predicted_label'] = y_pred.tolist()
dataset.head()

# %%
dataset.to_csv("./drive/MyDrive/Orbital Python files/c3_Predicted_Sentiments_Fresh_Dump.tsv", sep='\t', encoding='UTF-8', index=False)
